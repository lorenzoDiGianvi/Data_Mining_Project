# %%
# %matplotlib inline
import math
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Train_HR_Employee_Attrition.csv')

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1176.000000  1176.000000       1176.000000  1176.000000
# mean     37.199000   803.650510          9.210034     2.884354
# std       8.313199   406.683045          8.097024     1.016574
# min      18.000000   102.000000          1.000000     1.000000
# 25%      31.000000   460.500000          2.000000     2.000000
# 50%      37.199000   804.000000          7.000000     3.000000
# 75%      42.000000  1169.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1176.000000  1176.000000     1176.000000  1176.000000
# mean                  2.715986    66.299320        2.735544     2.021259
# std                   1.088876    20.266116        0.716228     1.069686
# min                   1.000000    30.000000        1.000000     1.000000
# ...

# %%
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000  -0.027961          0.008081   0.005951
# DailyRate                -0.027961   1.000000          0.014447  -0.014759
# DistanceFromHome          0.008081   0.014447          1.000000   0.021564
# Education                 0.005951  -0.014759          0.021564   1.000000
# EnvironmentSatisfaction   0.026259   0.047369          0.000980  -0.054301
# HourlyRate                0.045007   0.007709          0.037306   0.007589
# JobInvolvement            0.005358   0.049508         -0.009932   0.039782
# JobLevel                  0.040556  -0.009872          0.020217   0.086789
# JobSatisfaction          -0.056664   0.044478          0.004533  -0.036841
# MonthlyIncome             0.496275  -0.030414          0.000690   0.008964
# MonthlyRate               0.032088  -0.031826          0.007779  -0.017993
# ...

# %%
fig2 = plt.figure(figsize=(10, 10)) 
fig_dims = (3, 3)

plt.subplot2grid(fig_dims, (0, 0))
g = df['Age'].plot(kind = 'hist', title = 'Age')

plt.subplot2grid(fig_dims, (0, 1))
df['Education'].value_counts().plot(kind='bar', title='Education')

plt.subplot2grid(fig_dims, (1, 0))
df['MonthlyIncome'].plot(kind='hist', title='MonthlyIncome')

plt.subplot2grid(fig_dims, (1, 1))
df['DailyRate'].plot(kind='hist', title='DailyRate')

plt.subplot2grid(fig_dims, (2, 0))
df['TotalWorkingYears'].plot(kind='hist', title='TotalWorkingYears')
# Out:
# <AxesSubplot:title={'center':'TotalWorkingYears'}, ylabel='Frequency'>

# %%
df['EducationField'].value_counts().plot(kind = 'bar', title= 'edc.field') #per variabili categoriche serve il .value_counts()
# Out:
# <AxesSubplot:title={'center':'edc.field'}>

# %%
df['Gender'].value_counts().plot(kind = 'bar', title= 'Gender')
# Out:
# <AxesSubplot:title={'center':'Gender'}>

# %%
categorici = ['Attrition', 'BusinessTravel', 'Department', 'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobRole', 'JobLevel', 'JobSatisfaction', 'MaritalStatus', 'Over18', 'OverTime', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'WorkLifeBalance']

# %%
fig2 = plt.figure(figsize=(16, 16)) 
fig_dims = (3, 3)


plt.subplot2grid(fig_dims, (0, 0))
df['Attrition'].value_counts().plot(kind='bar', title='Attrition')

plt.subplot2grid(fig_dims, (0, 1))
df['BusinessTravel'].value_counts().plot(kind='bar', title='BusinessTravel')

plt.subplot2grid(fig_dims, (1, 0))
df['Department'].value_counts().plot(kind='bar', title='Department')

plt.subplot2grid(fig_dims, (1, 1))
df['Education'].value_counts().plot(kind='bar', title='Education')

plt.subplot2grid(fig_dims, (0, 2))
df['EducationField'].value_counts().plot(kind='bar', title='EducationField')

plt.subplot2grid(fig_dims, (2, 0))
df['EnvironmentSatisfaction'].value_counts().plot(kind='bar', title='EnvironmentSatisfaction')

# %%
fig2 = plt.figure(figsize=(17, 17)) 
fig_dims = (3, 3)


plt.subplot2grid(fig_dims, (0, 0))
df['Gender'].value_counts().plot(kind='bar', title='Gender')

plt.subplot2grid(fig_dims, (0, 1))
df['JobInvolvement'].value_counts().plot(kind='bar', title='JobInvolvement')

plt.subplot2grid(fig_dims, (1, 0))
df['JobRole'].value_counts().plot(kind='bar', title='JobRole')

plt.subplot2grid(fig_dims, (1, 1))
df['JobLevel'].value_counts().plot(kind='bar', title='JobLevel')

plt.subplot2grid(fig_dims, (0, 2))
df['JobSatisfaction'].value_counts().plot(kind='bar', title='JobSatisfaction')

plt.subplot2grid(fig_dims, (2, 0))
df['MaritalStatus'].value_counts().plot(kind='bar', title='MaritalStatus')

# %%
fig2 = plt.figure(figsize=(10, 10)) 
fig_dims = (3, 3)


plt.subplot2grid(fig_dims, (0, 0))
df['Over18'].value_counts().plot(kind='bar', title='Over18')

plt.subplot2grid(fig_dims, (0, 1))
df['OverTime'].value_counts().plot(kind='bar', title='OverTime')

plt.subplot2grid(fig_dims, (1, 0))
df['PerformanceRating'].value_counts().plot(kind='bar', title='PerformanceRating')

plt.subplot2grid(fig_dims, (1, 1))
df['RelationshipSatisfaction'].value_counts().plot(kind='bar', title='RelationshipSatisfaction')

plt.subplot2grid(fig_dims, (0, 2))
df['StockOptionLevel'].value_counts().plot(kind='bar', title='StockOptionLevel')

plt.subplot2grid(fig_dims, (2, 0))
df['WorkLifeBalance'].value_counts().plot(kind='bar', title='WorkLifeBalance')
# Out:
# <AxesSubplot:title={'center':'WorkLifeBalance'}>

# %%
fig2 = plt.figure(figsize=(16, 16)) 
fig_dims = (3, 2)


plt.subplot2grid(fig_dims, (0, 0))
df['Age'].plot(kind='hist', title='Age',bins=15)

plt.subplot2grid(fig_dims, (1, 0))
df['DailyRate'].plot(kind='hist', title='DailyRate')


plt.subplot2grid(fig_dims, (0, 1))
df['DistanceFromHome'].plot(kind='hist', title='DistanceFromHome')

plt.subplot2grid(fig_dims, (1, 1))
df['HourlyRate'].plot(kind='hist', title='HourlyRate')

plt.subplot2grid(fig_dims, (2, 0))
df['MonthlyIncome'].plot(kind='hist', title='MonthlyIncome')
# Out:
# <AxesSubplot:title={'center':'MonthlyIncome'}, ylabel='Frequency'>

# %%
fig2 = plt.figure(figsize=(16, 16)) 
fig_dims = (3, 2)


plt.subplot2grid(fig_dims, (0, 0))
df['MonthlyRate'].plot(kind='hist', title='MonthlyRate',bins = 15)

plt.subplot2grid(fig_dims, (1, 0))
df['NumCompaniesWorked'].plot(kind='hist', title='NumCompaniesWorked',bins = 15)


plt.subplot2grid(fig_dims, (0, 1))
df['PercentSalaryHike'].plot(kind='hist', title='PercentSalaryHike', bins = 15)

plt.subplot2grid(fig_dims, (1, 1))
df['StandardHours'].plot(kind='hist', title='StandardHours',bins = 15)

plt.subplot2grid(fig_dims, (2, 0))
df['TotalWorkingYears'].plot(kind='hist', title='TotalWorkingYears',bins = 15)
# Out:
# <AxesSubplot:title={'center':'TotalWorkingYears'}, ylabel='Frequency'>

# %%
fig2 = plt.figure(figsize=(16, 16)) 
fig_dims = (3, 2)


plt.subplot2grid(fig_dims, (0, 0))
df['TrainingTimesLastYear'].plot(kind='hist', title='TrainingTimesLastYear',bins = 10)

plt.subplot2grid(fig_dims, (1, 0))
df['YearsAtCompany'].plot(kind='hist', title='YearsAtCompany',bins = 15)


plt.subplot2grid(fig_dims, (0, 1))
df['YearsInCurrentRole'].plot(kind='hist', title='YearsInCurrentRole', bins = 15)

plt.subplot2grid(fig_dims, (1, 1))
df['YearsSinceLastPromotion'].plot(kind='hist', title='YearsSinceLastPromotion',bins = 15)

plt.subplot2grid(fig_dims, (2, 0))
df['YearsWithCurrManager'].plot(kind='hist', title='YearsWithCurrManager',bins = 15)
# Out:
# <AxesSubplot:title={'center':'YearsWithCurrManager'}, ylabel='Frequency'>

# %%
pclass_xt = pd.crosstab(df['BusinessTravel'], df['Department'])
pclass_xt

pclass_xt.plot(kind='bar', stacked=False, 
                   title='Survival Rate by Passenger Classes')
plt.xlabel('BusinessTravel')
plt.ylabel('Department')
plt.show()

# %%
pclass_xt = pd.crosstab(df['EducationField'], df['JobLevel'])
pclass_xt

pclass_xt.plot(kind='bar', stacked=False, 
                   title='Survival Rate by Passenger Classes')
plt.xlabel('BusinessTravel')
plt.ylabel('Department')
plt.show()

# %%
pclass_xt = pd.crosstab(df['JobLevel'], df['JobSatisfaction'])
pclass_xt

pclass_xt.plot(kind='bar', stacked=False, 
                   title='Survival Rate by Passenger Classes')
plt.xlabel('JobSatisfaction')
plt.ylabel('JobLevel')
plt.show()

# %%
pclass_xt = pd.crosstab(df['Attrition'], df['EnvironmentSatisfaction'])
pclass_xt

pclass_xt.plot(kind='bar', stacked=False, 
                   title='Survival Rate by Passenger Classes')
plt.xlabel('JobSatisfaction')
plt.ylabel('JobLevel')
plt.show()

# %%
df["Age"].fillna(df["Age"].mean(), inplace=True)
df['Age'].plot(kind='hist', title='Age',bins=15)
# Out:
# <AxesSubplot:title={'center':'Age'}, ylabel='Frequency'>

# %%
df['MonthlyIncome'].plot(kind='hist', title='MI')
# Out:
# <AxesSubplot:title={'center':'MI'}, ylabel='Frequency'>

# %%
df['MonthlyIncome'].fillna(df["MonthlyIncome"].mean(), inplace=True)
df['MonthlyIncome'].plot(kind='hist', title='MonthlyIncome',bins=10)
# Out:
# <AxesSubplot:title={'center':'MonthlyIncome'}, ylabel='Frequency'>

# %%
df['TrainingTimesLastYear'].plot(kind='hist', title='TrainingTimesLastYear',bins=10)
# Out:
# <AxesSubplot:title={'center':'TrainingTimesLastYear'}, ylabel='Frequency'>

# %%
df['TrainingTimesLastYear'].fillna(df["TrainingTimesLastYear"].mean(), inplace=True)
df['TrainingTimesLastYear'].plot(kind='hist', title='TrainingTimesLastYear',bins=10)
# Out:
# <AxesSubplot:title={'center':'TrainingTimesLastYear'}, ylabel='Frequency'>

# %%
#mediana di TrainingTimesLastYear per Department
df['TrainingTimesLastYear'].groupby(
    [df['Department']]).median()
# Out:
# Department
# Human Resources           3.0
# Research & Development    3.0
# Sales                     3.0
# Name: TrainingTimesLastYear, dtype: float64

# %%
#moda di TrainingTimesLastYear per Department
df['TrainingTimesLastYear'].groupby(
    [df['Department']]).agg(pd.Series.mode)
# Out:
# Department
# Human Resources           3.0
# Research & Development    2.0
# Sales                     2.0
# Name: TrainingTimesLastYear, dtype: float64

# %%
#riempire i Nan di TrainingTimesLastYear con la moda 
i = 0
for record in df['TrainingTimesLastYear']:
    if not pd.notnull(record):
        if df.at[i, 'Department'] == "Human Resources":
            df.at[i, 'TrainingTimesLastYear'] = 3.0
        elif df.at[i, 'Department'] == "Research & Development":
            df.at[i, 'TrainingTimesLastYear'] = 2.0
        elif df.at[i, 'Department'] == "Sales":
            df.at[i, 'TrainingTimesLastYear'] = 2.0
    i += 1
df['TrainingTimesLastYear'].isnull().sum()
# Out:
# 0

# %%
#funzione per aggiornare i valori mancanti tramite la Y
i=0
X = df.values
for record in df['MonthlyIncome']:
    if not pd.notnull(record):
        record = 391.4 * X[i, 29] + 3763.8
        df.at[i, 'MonthlyIncome'] = record
    i += 1

# %%
df['MonthlyIncome'][12]
# Out:
# 17071.399999999998

# %%
#funzione per aggiornare i valori mancanti di BT con il valore più frequente
i = 0
for record in df['BusinessTravel']:
    if not pd.notnull(record):
        df.at[i, 'BusinessTravel'] = "Travel_Rarely"
    i += 1
df['BusinessTravel'].isnull().sum()
# Out:
# 0

# %%
#funzione per riempire i valori di gender con ND
i = 0
for record in df['Gender']:
    if not pd.notnull(record):
        df.at[i, 'Gender']= 'ND'
    i+=1
df['Gender'].isnull().sum()
# Out:
# 0

# %%
boxplot = df.boxplot(column=['Age'])

# %%
boxplot = df.boxplot(column=['DailyRate'])

# %%
boxplot = df.boxplot(column=['DistanceFromHome'])

# %%
boxplot = df.boxplot(column=['MonthlyIncome'])

# %%
boxplot = df.boxplot(column=['MonthlyRate'])

# %%
boxplot = df.boxplot(column=['NumCompaniesWorked'])

# %%
boxplot = df.boxplot(column=['PercentSalaryHike'])

# %%
boxplot = df.boxplot(column=['TotalWorkingYears'])

# %%
boxplot = df.boxplot(column=['TrainingTimesLastYear'])

# %%
boxplot = df.boxplot(column=['YearsAtCompany'])

# %%
boxplot = df.boxplot(column=['NumCompaniesWorked'])

# %%
boxplot = df.boxplot(column=['YearsSinceLastPromotion'])

# %%
boxplot = df.boxplot(column=['YearsWithCurrManager'])

# %%
boxplot = df.boxplot(column=['YearsInCurrentRole'])

# %%
i=0
for record in df['Age']:
    if record > 58:
        i+=1
i
# Out:
# 10

# %%
i=0
for record in df['MonthlyIncome']:
    if record > 17000:
        i+=1
i
# Out:
# 64

# %%
i=0
for record in df['TotalWorkingYears']:
    if record > 28:
        i+=1
i
# Out:
# 49

# %%
i=0
for record in df['TrainingTimesLastYear']:
    if record >= 5:
        i+=1
i
# Out:
# 120

# %%
i=0
for record in df['YearsAtCompany']:
    if record >= 18:
        i+=1
i
# Out:
# 84

# %%
i=0
for record in df['NumCompaniesWorked']:
    if record > 8:
        i+=1
i
# Out:
# 40

# %%
i=0
for record in df['YearsSinceLastPromotion']:
    if record > 7:
        i+=1
i
# Out:
# 85

# %%
i=0
for record in df['YearsWithCurrManager']:
    if record > 13:
        i+=1
i
# Out:
# 16

# %%
i=0
for record in df['YearsInCurrentRole']:
    if record > 14:
        i+=1
i
# Out:
# 17

# %%
df['Department'].value_counts()
# Out:
# Research & Development    769
# Sales                     361
# Human Resources            46
# Name: Department, dtype: int64

# %%
df['Attrition'].value_counts()
# Out:
# No     984
# Yes    192
# Name: Attrition, dtype: int64

# %%
df['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        764
# Travel_Frequently    192
# Non-Travel           113
# Name: BusinessTravel, dtype: int64

# %%
df['Education'].value_counts()
# Out:
# 3    459
# 4    312
# 2    234
# 1    139
# 5     32
# Name: Education, dtype: int64

# %%
df['EducationField'].value_counts()
# Out:
# Life Sciences       489
# Medical             370
# Marketing           125
# Technical Degree    107
# Other                64
# Human Resources      21
# Name: EducationField, dtype: int64

# %%
df['EnvironmentSatisfaction'].value_counts()
# Out:
# 3    366
# 4    351
# 2    233
# 1    226
# Name: EnvironmentSatisfaction, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male      664
# Female    453
# Name: Gender, dtype: int64

# %%
df['JobInvolvement'].value_counts()
# Out:
# 3    686
# 2    303
# 4    122
# 1     65
# Name: JobInvolvement, dtype: int64

# %%
df['JobSatisfaction'].value_counts()
# Out:
# 4    355
# 3    351
# 2    235
# 1    235
# Name: JobSatisfaction, dtype: int64

# %%
df['JobRole'].value_counts()
# Out:
# Sales Executive              261
# Research Scientist           240
# Laboratory Technician        212
# Manufacturing Director       115
# Healthcare Representative    106
# Manager                       81
# Sales Representative          69
# Research Director             51
# Human Resources               41
# Name: JobRole, dtype: int64

# %%
df['JobLevel'].value_counts()
# Out:
# 1    446
# 2    429
# 3    175
# 4     82
# 5     44
# Name: JobLevel, dtype: int64

# %%
df['MaritalStatus'].value_counts()
# Out:
# Married     542
# Single      383
# Divorced    251
# Name: MaritalStatus, dtype: int64

# %%
df['StockOptionLevel'].value_counts()
# Out:
# 0    514
# 1    470
# 2    125
# 3     67
# Name: StockOptionLevel, dtype: int64

# %%
df['PerformanceRating'].value_counts()
# Out:
# 3.0    880
# 4.0    158
# Name: PerformanceRating, dtype: int64

# %%
df['RelationshipSatisfaction'].value_counts()
# Out:
# 3    354
# 4    350
# 2    244
# 1    228
# Name: RelationshipSatisfaction, dtype: int64

# %%
df['WorkLifeBalance'].value_counts()
# Out:
# 3    718
# 2    272
# 4    119
# 1     67
# Name: WorkLifeBalance, dtype: int64

# %%
dfr = df[df['Age']<=58]
dfr = dfr[dfr['MonthlyIncome']<=17009]
# Out:
# pandas.core.frame.DataFrame

# %%
df.sort_values(by='Age',ascending=True, na_position='first')
# Out:
#        Age Attrition BusinessTravel  DailyRate              Department  \
# 310   18.0        No  Travel_Rarely        470  Research & Development
# 396   18.0        No     Non-Travel        895  Research & Development
# 1013  18.0        No            NaN        879  Research & Development
# 296   18.0       Yes     Non-Travel        827  Research & Development
# 263   18.0        No     Non-Travel       1329  Research & Development
# ...    ...       ...            ...        ...                     ...
# 207   59.0        No            NaN        611                   Sales
# 92    60.0        No  Travel_Rarely        529  Research & Development
# 720   60.0       Yes  Travel_Rarely        504  Research & Development
# 64    60.0       Yes  Travel_Rarely       1373  Research & Development
# 336   60.0        No  Travel_Rarely        702  Research & Development
#
#       DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# ...

# %%
df = df.sort_values(by='Age',ascending=True, na_position='first')
df
# Out:
#        Age Attrition BusinessTravel  DailyRate              Department  \
# 310   18.0        No  Travel_Rarely        470  Research & Development
# 396   18.0        No     Non-Travel        895  Research & Development
# 1013  18.0        No            NaN        879  Research & Development
# 296   18.0       Yes     Non-Travel        827  Research & Development
# 263   18.0        No     Non-Travel       1329  Research & Development
# ...    ...       ...            ...        ...                     ...
# 207   59.0        No            NaN        611                   Sales
# 92    60.0        No  Travel_Rarely        529  Research & Development
# 720   60.0       Yes  Travel_Rarely        504  Research & Development
# 64    60.0       Yes  Travel_Rarely       1373  Research & Development
# 336   60.0        No  Travel_Rarely        702  Research & Development
#
#       DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# ...

# %%
dfr = df.sort_values(by='Age',ascending=True, na_position='first')

# %%
df.Age.ne('59').idxmax()
# Out:
# /opt/anaconda3/envs/DM/lib/python3.8/site-packages/pandas/core/computation/expressions.py:68: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return op(a, b)
# 310

# %%
dfr
# Out:
#        Age Attrition BusinessTravel  DailyRate              Department  \
# 310   18.0        No  Travel_Rarely        470  Research & Development
# 396   18.0        No     Non-Travel        895  Research & Development
# 1013  18.0        No            NaN        879  Research & Development
# 296   18.0       Yes     Non-Travel        827  Research & Development
# 263   18.0        No     Non-Travel       1329  Research & Development
# ...    ...       ...            ...        ...                     ...
# 612   59.0        No  Travel_Rarely       1153  Research & Development
# 64    60.0       Yes  Travel_Rarely       1373  Research & Development
# 92    60.0        No  Travel_Rarely        529  Research & Development
# 720   60.0       Yes  Travel_Rarely        504  Research & Development
# 336   60.0        No  Travel_Rarely        702  Research & Development
#
#       DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# ...

# %%
df.to_csv(index=False)
# Out:
# 'Age,Attrition,BusinessTravel,DailyRate,Department,DistanceFromHome,Education,EducationField,EnvironmentSatisfaction,Gender,HourlyRate,JobInvolvement,JobLevel,JobRole,JobSatisfaction,MaritalStatus,MonthlyIncome,MonthlyRate,NumCompaniesWorked,Over18,OverTime,PercentSalaryHike,PerformanceRating,RelationshipSatisfaction,StandardHours,StockOptionLevel,TotalWorkingYears,TrainingTimesLastYear,WorkLifeBalance,YearsAtCompany,YearsInCurrentRole,YearsSinceLastPromotion,YearsWithCurrManager\n18.0,No,Travel_Rarely,470,Research & Development,20,4,Medical,3,Female,96,3,2,Manufacturing Director,1,Married,1200.0,5549,1,,No,14,3.0,3,80.0,0,16,2.0,2,0.0,11,5,11\n18.0,No,Non-Travel,895,Research & Development,15,2,Life Sciences,1,Male,50,3,1,Laboratory Technician,3,Divorced,1904.0,22482,1,Y,No,16,3.0,4,,1,4,0.0,2,0.0,2,2,2\n18.0,No,,879,Research & Development,9,2,Medical,3,Male,72,3,2,Manufacturing Director,3,Single,1878.0,12858,7,,Yes,18,,3,80.0,0,10,3.0,3,0.0,4,1,7\n18.0,Yes,Non-Travel,827,Research & 
# ...

# %%
dfnew = pd.read_csv('no_outlier.csv', sep=';')

# %%
i=0
for record in dfnew['Age']:
    dfnew.at[i, 'Age'] = record / 10
    i+=1
    
dfnew
# Out:
#        Age Attrition     BusinessTravel  DailyRate              Department  \
# 0     37.0        No      Travel_Rarely        625  Research & Development
# 1      NaN        No      Travel_Rarely       1272  Research & Development
# 2     36.0       Yes      Travel_Rarely       1141  Research & Development
# 3     24.0        No      Travel_Rarely       1332  Research & Development
# 4     58.0        No      Travel_Rarely       1456  Research & Development
# ...    ...       ...                ...        ...                     ...
# 1008  28.0        No                NaN        202                   Sales
# 1009  35.0       Yes      Travel_Rarely        350                   Sales
# 1010  41.0       Yes  Travel_Frequently        703                   Sales
# 1011   NaN       Yes      Travel_Rarely        337                   Sales
# 1012  38.0       Yes      Travel_Rarely        156                   Sales
#
# ...

# %%
i = 0
for record in dfnew['MonthlyIncome']:
    dfnew.at[i, 'MonthlyIncome']= record /10
    i+=1
    
dfnew
# Out:
#        Age Attrition     BusinessTravel  DailyRate              Department  \
# 0     37.0        No      Travel_Rarely        625  Research & Development
# 1      NaN        No      Travel_Rarely       1272  Research & Development
# 2     36.0       Yes      Travel_Rarely       1141  Research & Development
# 3     24.0        No      Travel_Rarely       1332  Research & Development
# 4     58.0        No      Travel_Rarely       1456  Research & Development
# ...    ...       ...                ...        ...                     ...
# 1008  28.0        No                NaN        202                   Sales
# 1009  35.0       Yes      Travel_Rarely        350                   Sales
# 1010  41.0       Yes  Travel_Frequently        703                   Sales
# 1011   NaN       Yes      Travel_Rarely        337                   Sales
# 1012  38.0       Yes      Travel_Rarely        156                   Sales
#
# ...

# %%
correlation = dfnew.corr()

# %%
pd.plotting.scatter_matrix(dfnew[['Age','MonthlyIncome', 'YearsAtCompany', 'TotalWorkingYears']])
plt.show()

# %%
sns.set(style="white")

# Generate a mask for the upper triangle
mask = np.zeros_like(correlation, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlation, mask=mask, cmap=cmap, vmax=.7, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
#AGGIUNGIAMO I VALORI MANCANTI

# %%
dfnew["Age"].fillna(dfnew["Age"].mean(), inplace=True)


dfnew['Age'].hist()
# Out:
# <AxesSubplot:>

# %%
#funzione per aggiornare i valori mancanti di BT con il valore più frequente
i = 0
for record in dfnew['BusinessTravel']:
    if not pd.notnull(record):
        dfnew.at[i, 'BusinessTravel'] = "Travel_Rarely"
    i += 1
dfnew['BusinessTravel'].isnull().sum()
# Out:
# 0

# %%
#funzione per aggiornare i valori mancanti di Gender con ND
i = 0
for record in dfnew['Gender']:
    if not pd.notnull(record):
        dfnew.at[i, 'Gender'] = "ND"
    i += 1
dfnew['Gender'].isnull().sum()
# Out:
# 0

# %%
#funzione per aggiornare i valori mancanti tramite la Y
i=0
X = dfnew.values
for record in dfnew['MonthlyIncome']:
    if not pd.notnull(record):
        record = 391.4 * X[i, 29] + 3763.8
        dfnew.at[i, 'MonthlyIncome'] = record
    i += 1

dfnew['MonthlyIncome'].isnull().sum()
# Out:
# 0

# %%
dfnew['YearsInCurrentRole'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
18-20 1
21-30 3
31-40 10
41-50 8
51-60 10

# %%
#funzione per trattare i valori mancanti di yearsatcompany
i = 0
for record in dfnew['YearsAtCompany']:
    if not pd.notnull(record):
        if dfnew.at[i,'Age'] < 21:
            dfnew.at[i, 'YearsAtCompany']= 1
        elif dfnew.at[i,'Age'] < 31:
            dfnew.at[i, 'YearsAtCompany']= 3
        elif dfnew.at[i,'Age'] < 41:
            dfnew.at[i, 'YearsAtCompany']= 10
        elif dfnew.at[i,'Age'] < 51:
            dfnew.at[i, 'YearsAtCompany']= 8
        elif dfnew.at[i,'Age'] < 61:
            dfnew.at[i, 'YearsAtCompany']= 10
    i += 1
    
dfnew['YearsAtCompany'].isnull().sum()
# Out:
# 0

# %%
#riempire i Nan di TrainingTimesLastYear con la moda 
i = 0
for record in dfnew['TrainingTimesLastYear']:
    if not pd.notnull(record):
        if dfnew.at[i, 'Department'] == "Human Resources":
            dfnew.at[i, 'TrainingTimesLastYear'] = 3.0
        elif dfnew.at[i, 'Department'] == "Research & Development":
            dfnew.at[i, 'TrainingTimesLastYear'] = 2.0
        elif dfnew.at[i, 'Department'] == "Sales":
            dfnew.at[i, 'TrainingTimesLastYear'] = 2.0
    i += 1
dfnew['TrainingTimesLastYear'].isnull().sum()
# Out:
# 0

# %%
dfnew.isnull().sum()
# Out:
# Age                           0
# Attrition                     0
# BusinessTravel                0
# DailyRate                     0
# Department                    0
# DistanceFromHome              0
# Education                     0
# EducationField                0
# EnvironmentSatisfaction       0
# Gender                        0
# HourlyRate                    0
# JobInvolvement                0
# JobLevel                      0
# JobRole                       0
# JobSatisfaction               0
# MaritalStatus                 0
# MonthlyIncome                 0
# MonthlyRate                   0
# NumCompaniesWorked            0
# Over18                      320
# OverTime                      0
# PercentSalaryHike             0
# PerformanceRating           123
# RelationshipSatisfaction      0
# StandardHours               500
# StockOptionLevel              0
# TotalWorkingYears             0
# TrainingTimesLastYear         0
# WorkLifeBalance               0
# ...

# %%
correlazione_dfnew = dfnew.corr()

# %%
sns.set(style="white")

# Generate a mask for the upper triangle
mask = np.zeros_like(correlazione_dfnew, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlazione_dfnew, mask=mask, cmap=cmap, vmax=.7, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
pd.plotting.scatter_matrix(dfnew[['JobLevel','YearsInCurrentRole', 'TotalWorkingYears','YearsSinceLastPromotion', 'YearsWithCurrManager']], figsize=(15.0,15.0))
plt.show()
